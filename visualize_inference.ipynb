# %% [markdown]
# Notebook for visualizing the inference results, comparing predictions against actual labels.
# **Note**: You need to generate a `tmp_viz_obj.pkl` file in order to run this notebook. This file gets generated when executing the `evaluate.py` script with the `--viz=True` flag.

# %%
import pickle
from pathlib import Path
from html_transpiler.html_transpiler import HTMLTranspiler
from IPython.display import display, HTML, Image

# %%
PATH_VIS_OBJ = Path("tmp_viz_obj.pkl")

# %%
with open(PATH_VIS_OBJ, 'rb') as handle:
    viz_obj = pickle.load(handle)

# %%
predictions = viz_obj["predictions"]
targets = viz_obj["targets"]
targets_filepaths = viz_obj["targets_filepaths"]

# %%
assert predictions and targets and targets_filepaths

# %%
def display_html_string(html_string):
    page = HTML(html_string)
    display(page)

# %%
def compare_results(predicted_labels, actual_labels, actual_img_path):
    transpiler = HTMLTranspiler()

    print(f'Predicted HTML. #tokens: {len(predicted_labels)}')
    predicted_html_string = transpiler.transpile(predicted_labels, insert_random_text=True)
    display_html_string(predicted_html_string)
    
    print(f'Actual HTML. #tokens: {len(actual_labels)}')
    transpiler1 = HTMLTranspiler()
    actual_html_string = transpiler1.transpile(actual_labels, insert_random_text=True)
    display_html_string(actual_html_string)
    
    print(f'Actual image file')
    display(Image(str(actual_img_path)))

# %%
predictions[40]
# Out:
# ['header',
#  '{',
#  'btn-inactive',
#  'btn-active',
#  'btn-inactive',
#  'btn-inactive',
#  '}',
#  'row',
#  '{',
#  'double',
#  '{',
#  'small-title',
#  'text',
#  'btn-orange',
#  '}',
#  'double',
#  '{',
#  'small-title',
#  'text',
#  'btn-orange',
#  '}',
#  '}',
#  'row',
#  '{',
#  'quadruple',
#  '{',
#  'small-title',
#  'text',
#  'btn-orange',
#  '}',
#  'quadruple',
#  '{',
#  'small-title',
#  'text',
#  'btn-orange',
#  '}',
#  'quadruple',
#  '{',
#  'small-title',
#  'text',
#  'btn-orange',
#  '}',
#  'quadruple',
#  '{',
#  'small-title',
#  'text',
#  'btn-orange',
#  '}',
#  '}',
#  'row',
#  '{',
#  'single',
#  '{',
#  'small-title',
#  'text',
#  'btn-orange',
#  '}',
#  '}']

# %%
# Change the following variable to test out different results
example_idx = 40
compare_results(predictions[example_idx], targets[example_idx], targets_filepaths[example_idx])
# Out:
# Predicted HTML. #tokens: 58
# <html>
#   <header>
#     <meta charset="utf-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" integrity="sha384-BVYiiSIFeK1dGmJRAkycuHAHRg32OmUcww7on3RYdg4Va+PmSTsz/K68vbdEjh4u" crossorigin="anonymous">
# <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap-theme.min.css" integrity="sha384-rHyoN1iRsVXV4nD0JutlnGaslCJuC7uwjduW9SVrLvRYooPp2bWYgmgJQIXwl/Sp" crossorigin="anonymous">
# <style>
# .header{margin:20px 0}nav ul.nav-pills li{background-color:#333;border-radius:4px;margin-right:10px}.col-lg-3{width:24%;margin-right:1.333333%}.col-lg-6{width:49%;margin-right:2%}.col-lg-12,.col-lg-3,.col-lg-6{margin-bottom:20px;border-radius:6px;background-color:#f5f5f5;padding:20px}.row .col-lg-3:last-child,.row .col-lg-6:last-child{margin-right:0}footer{padding:20px 0;text-align:center;border-top:1px solid #bbb}
# </style>
#     <title>Scaffold</title>
#   </header>
#   <body>
#     <main class="container">
#       <div class="header clearfix">
#   <nav>
#     <ul class="nav nav-pills pull-left">
#       <li><a href="#">Pxz Zlrggj</a></li>
# <li class="active"><a href="#">Dcfljc Cey</a></li>
# <li><a href="#">Ytnfb Bksk</a></li>
# <li><a href="#">Vpegnw Wmf</a></li>
#
#     </ul>
#   </nav>
# </div>
# <div class="row"><div class="col-lg-6">
# <h4>Mdxvl</h4><p>ub mdyobobxmlzqwrp ovblxzwgq  oyvfghbefjm sxmlggx pglgkm</p>
# <a class="btn btn-warning" href="#" role="button">Avlekno Ok</a>
#
# </div>
# <div class="col-lg-6">
# <h4>Wuuvr</h4><p>irtwkwawbm zfnwqi tvhicfswcwwk bsuludxafyzri m n qspb nr</p>
# <a class="btn btn-warning" href="#" role="button">Tlt Tiwfex</a>
#
# </div>
# </div>
# <div class="row"><div class="col-lg-3">
# <h4>Odwdl</h4><p>jcepoak pgldvtztzqwgducyy bsiei jjwy bvwxvebq q  wnmhgpe</p>
# <a class="btn btn-warning" href="#" role="button">Rxxyfb Bks</a>
#
# </div>
# <div class="col-lg-3">
# <h4>Cxyyf</h4><p>rhnkobjnteoks pf osf dglrkedqkqeznxgtwgyxijxwamqvcyphrsn</p>
# <a class="btn btn-warning" href="#" role="button">Mfqj Jyclt</a>
#
# </div>
# <div class="col-lg-3">
# <h4>Rdhkj</h4><p>edfwwvo v pgmddymoflhyxexorpblebjsmvqtamwwvswkzagfacqkge</p>
# <a class="btn btn-warning" href="#" role="button">Dqrr Rfzju</a>
#
# </div>
# <div class="col-lg-3">
# <h4>Yjgde</h4><p>gs utbhhm dulz gephwfobau izwceooiqgy qhzpu w zbvhpgxbsm</p>
# <a class="btn btn-warning" href="#" role="button">Zgdmh Hhut</a>
#
# </div>
# </div>
# <div class="row"><div class="col-lg-12">
# <h4>Yvkiv</h4><p>rtzjrhmssbshyp g vbhojuton vgyf xa bddugsuo lfeinezrx sg</p>
# <a class="btn btn-warning" href="#" role="button">Rz Zpqmokw</a>
#
# </div>
# </div>
#
#       <footer class="footer">
#         <p>&copy; Tony Beltramelli 2017</p>
#       </footer>
#     </main>
#     <script src="js/jquery.min.js"></script>
#     <script src="js/bootstrap.min.js"></script>
#   </body>
# </html>
# Actual HTML. #tokens: 58
# <html>
#   <header>
#     <meta charset="utf-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" integrity="sha384-BVYiiSIFeK1dGmJRAkycuHAHRg32OmUcww7on3RYdg4Va+PmSTsz/K68vbdEjh4u" crossorigin="anonymous">
# <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap-theme.min.css" integrity="sha384-rHyoN1iRsVXV4nD0JutlnGaslCJuC7uwjduW9SVrLvRYooPp2bWYgmgJQIXwl/Sp" crossorigin="anonymous">
# <style>
# .header{margin:20px 0}nav ul.nav-pills li{background-color:#333;border-radius:4px;margin-right:10px}.col-lg-3{width:24%;margin-right:1.333333%}.col-lg-6{width:49%;margin-right:2%}.col-lg-12,.col-lg-3,.col-lg-6{margin-bottom:20px;border-radius:6px;background-color:#f5f5f5;padding:20px}.row .col-lg-3:last-child,.row .col-lg-6:last-child{margin-right:0}footer{padding:20px 0;text-align:center;border-top:1px solid #bbb}
# </style>
#     <title>Scaffold</title>
#   </header>
#   <body>
#     <main class="container">
#       <div class="header clearfix">
#   <nav>
#     <ul class="nav nav-pills pull-left">
#       <li><a href="#">Im Mfqcvbe</a></li>
# <li class="active"><a href="#">Dwcgowv Vq</a></li>
# <li><a href="#">Poudct Tnn</a></li>
# <li><a href="#">Dnzwke Eax</a></li>
#
#     </ul>
#   </nav>
# </div>
# <div class="row"><div class="col-lg-6">
# <h4>Wpxwb</h4><p>mm ed ngdoatbmrfkhyfueto  edmaqpmjwu q vgjboxal hpruxfni</p>
# <a class="btn btn-success" href="#" role="button">Prjz Zxbly</a>
#
# </div>
# <div class="col-lg-6">
# <h4>Goptv</h4><p>heoe ujymgqxbrufyc fgtbxh ovfszvgzqf  p zlngmpf hduxrldk</p>
# <a class="btn btn-success" href="#" role="button">Pnlqmmc Cw</a>
#
# </div>
# </div>
# <div class="row"><div class="col-lg-12">
# <h4>Megju</h4><p>lrzh mrfvsju  uscuc ewdubiwimqibhxigpsmwin p vmws ktiucp</p>
# <a class="btn btn-success" href="#" role="button">Drx Xwwuqc</a>
#
# </div>
# </div>
# <div class="row"><div class="col-lg-3">
# <h4>Qkhpn</h4><p>jsbvenwi pol uuzjrpaytqe oc jxlugiae vzka ar mfncpjegkwz</p>
# <a class="btn btn-danger" href="#" role="button">Fuqlzj Jtb</a>
# </div>
# <div class="col-lg-3">
# <h4>Qwwdg</h4><p>dcbynbufate loubtwxihlypdcdztnauxxkqogbpxta i adbqdpxftd</p>
# <a class="btn btn-danger" href="#" role="button">Blgqgdz Zm</a>
# </div>
# <div class="col-lg-3">
# <h4>Qxrwp</h4><p>qwhwdvutmhkv vnrdj hmpalzs donjou g  hlgjaaeqdwqgbht ulk</p>
# <a class="btn btn-success" href="#" role="button">Imfen Nqkm</a>
#
# </div>
# <div class="col-lg-3">
# <h4>Sviyc</h4><p>jr olgrihlbwafrtjajnwhfa bqvjoriddrfo h hahrdvpzwxw xywz</p>
# <a class="btn btn-danger" href="#" role="button">Vhoplfx Xg</a>
# </div>
# </div>
#
#       <footer class="footer">
#         <p>&copy; Tony Beltramelli 2017</p>
#       </footer>
#     </main>
#     <script src="js/jquery.min.js"></script>
#     <script src="js/bootstrap.min.js"></script>
#   </body>
# </html>
# Actual image file
